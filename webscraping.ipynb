# %%
import pandas as pd

# %%
df = pd.read_csv(
    "Database export - Clothing distribuiton EMEA - 2019-2021.csv", encoding="latin1"
)
df.drop("Unnamed: 0", axis=1, inplace=True)

df.head()
# Out:
#                     Company Name ISO Country Code               Country  \
# 0  ITX HELLAS SINGLE MEMBER S.A.               GR                 Grèce
# 1                        RANDEVU               RU  Fédération de Russie
# 2           ZEEMAN TEXTIELSUPERS               FR                France
# 3               ANSWEAR.COM S.A.               PL               Pologne
# 4                    REGENT GOLD               RU  Fédération de Russie
#
#                                          City  \
# 0                                      ATHENS
# 1                                      MOSCOW
# 2                                       PARIS
# 3                                      KRAKOW
# 4  AGALATOVSKOE SELSKOE POSELENIE, D. SKOTNOE
#
#                                           Address  NACE Rev. 2 Code principal  \
# 0                                             NaN                        4771
# 1             UL. SKAKOVAYA D. 17, STR. 2, KOM. 2                        4772
# 2                                             NaN                        4771
# 3                                             NaN                        4771
# 4  UL. SAVUSHKINA D. 126, LIT. A, POMESHCH. 133-N                        4777
#
#                  NACE Principal Rev. 2, description   \
# 0  Commerce de détail d'habillement en magasin sp...
# 1  Commerce de détail de chaussures et d'articles...
# 2  Commerce de détail d'habillement en magasin sp...
# 3  Commerce de détail d'habillement en magasin sp...
# 4  Commerce de détail d'articles d'horlogerie et ...
#
#                                               Sector  \
# 0          Engaged in the retail of fashion clothing
# 1  Engaged in the wholesale trade and marketing o...
# 2  Engaged in the retail sale of clothing and out...
# 3  Digital platform for the sale of branded cloth...
# 4     Operates as other miscellaneous store retailer
#
#                  Main activity  \
# 0                       Retail
# 1                    Wholesale
# 2                       Retail
# 3  Wholesale; Retail; Services
# 4                       Retail
#
#                     Description in Original language  ...  \
# 0                                                NaN  ...
# 1                     ?????????? ????? ? ???????????  ...
# 2  Négoce au détail ou en gros de vêtements, acce...  ...
# 3                                                NaN  ...
# 4                      ???????? ?????????? ?????????  ...
#
#                                    Website  \
# 0        www.zara.com\nwww.fashionwear1.gr
# 1  www.rendez-vous.ru\nwww.rest-randevu.ru
# 2                           www.zeeman.com
# 3                          www.answear.com
# 4                           www.zolotoy.ru
#
#   Operating result [=EBIT]\nmEUR 2021 Operating result [=EBIT]\nmEUR 2020  \
# 0                                  31                                  17
# 1                                  15                                  14
# 2                                   4                                   3
# 3                                   8                                   5
# 4                                  22                                  16
#
#   Operating result [=EBIT]\nmEUR 2019 Turnover\nmEUR 2021  \
# 0                                  22                 459
# 1                                   1                 306
# 2                                   4                 164
# 3                                   1                 149
# 4                                   5                 141
#
#    Turnover\nmEUR 2020  Turnover\nmEUR 2019  Availability of financial data  \
# 0                  352                  300                             YES
# 1                  230                  337                             YES
# 2                  137                  147                             YES
# 3                   90                   73                             YES
# 4                  103                  117                             YES
#
#   2 years of consecutive losses Average loss over 3 years
# 0                            NO                        NO
# 1                            NO                        NO
# 2                            NO                        NO
# 3                            NO                        NO
# 4                            NO                        NO
#
# [5 rows x 21 columns]

# %%
# ✅ 1. Clean column names (remove newlines)
df.columns = [col.replace("\n", " ").strip() for col in df.columns]

# %%
# ✅ 2. Split multiple website entries
df["Additional Websites"] = df["Website"].apply(lambda x: "\n".join(x.split("\n")[1:]) if isinstance(x, str) and "\n" in x else None)
df["Website"] = df["Website"].apply(lambda x: x.split("\n")[0] if isinstance(x, str) else x)

# %%
df['Website']
# Out:
# 0                            www.zara.com
# 1                      www.rendez-vous.ru
# 2                          www.zeeman.com
# 3                         www.answear.com
# 4                          www.zolotoy.ru
#                       ...
# 485                                   NaN
# 486                  www.cortinadecor.com
# 487                         www.tezuk.com
# 488    www.cralregionesardegna.it/?p=2693
# 489                   www.markt-kontor.de
# Name: Website, Length: 490, dtype: object

# %%
df['Additional Websites']
# Out:
# 0      www.fashionwear1.gr
# 1      www.rest-randevu.ru
# 2                     None
# 3                     None
# 4                     None
#               ...
# 485                   None
# 486                   None
# 487           www.zetek.it
# 488                   None
# 489                   None
# Name: Additional Websites, Length: 490, dtype: object

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
# ✅ Set up Selenium for JavaScript-rendered websites
options = Options()
options.add_argument("--headless")  # Run in background
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
def get_metadata(url):
    if not isinstance(url, str) or len(url) < 5:
        return {"Meta Title": None, "Meta Description": None, "Meta Keywords": None}

    # Ensure the URL has a proper scheme
    if not url.startswith(("http://", "https://")):
        url = "https://" + url  # Default to HTTPS

    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=5)

        # If requests fail, use Selenium (handles JavaScript)
        if response.status_code != 200:
            driver.get(url)
            page_source = driver.page_source
            soup = BeautifulSoup(page_source, "html.parser")
        else:
            soup = BeautifulSoup(response.text, "html.parser")

        # Extract metadata
        title = soup.title.string.strip() if soup.title else None
        meta_desc = soup.find("meta", attrs={"name": "description"})
        meta_desc = meta_desc["content"].strip() if meta_desc else None
        meta_keywords = soup.find("meta", attrs={"name": "keywords"})
        meta_keywords = meta_keywords["content"].strip() if meta_keywords else None

        return {"Meta Title": title, "Meta Description": meta_desc, "Meta Keywords": meta_keywords}

    except Exception as e:
        return {"Meta Title": None, "Meta Description": None, "Meta Keywords": None}

# %%
# ✅ Apply function to extract metadata
df["Metadata"] = df["Website"].apply(get_metadata)

# %%
df["Metadata"]
# Out:
# 0      {'Meta Title': '', 'Meta Description': None, '...
# 1      {'Meta Title': 'Интернет-магазин обуви и одежд...
# 2      {'Meta Title': 'Zeeman. Zo eenvoudig kan het z...
# 3      {'Meta Title': 'Answear.com sklep internetowy ...
# 4      {'Meta Title': 'Женский интернет-журнал "ЗОЛОТ...
#                              ...
# 485    {'Meta Title': None, 'Meta Description': None,...
# 486    {'Meta Title': 'Cortinadecor.com | Estores y c...
# 487    {'Meta Title': 'Tezuk | Tezuk beachwear | Shop...
# 488    {'Meta Title': 'Cral Regione Sardegna - eventi...
# 489    {'Meta Title': 'Home', 'Meta Description': '',...
# Name: Metadata, Length: 490, dtype: object

# %%
# ✅ Expand dictionary into separate columns
df = df.join(pd.DataFrame(df.pop("Metadata").tolist()))

# %%
df.to_csv("metadata1.csv", index=False)

# %%
import ace_tools as tools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import ace_tools as tools
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
df[["Company Name", "Website", "Meta Title", "Meta Description"]].head(10)  # View first 10 rows
# Out:
#                               Company Name                     Website  \
# 0            ITX HELLAS SINGLE MEMBER S.A.                www.zara.com
# 1                                  RANDEVU          www.rendez-vous.ru
# 2                     ZEEMAN TEXTIELSUPERS              www.zeeman.com
# 3                         ANSWEAR.COM S.A.             www.answear.com
# 4                              REGENT GOLD              www.zolotoy.ru
# 5                      WOLW-POL SP. Z O.O.           www.dieselshop.pl
# 6             NILSON GROUP AB FILIAL NORGE                         NaN
# 7                               SAKURA LLC  xn--23-6kca3cvbes.xn--p1ai
# 8  LIMITED LIABILITY COMPANY HUGO BOSS RUS         www.hugoboss.com/ru
# 9                   MNG-MANGO U.K. LIMITED          www.shop.mango.com
#
#                                           Meta Title  \
# 0
# 1           Интернет-магазин обуви и одежды в Москве
# 2                 Zeeman. Zo eenvoudig kan het zijn.
# 3  Answear.com sklep internetowy z modą damską, m...
# 4                  Женский интернет-журнал "ЗОЛОТОЙ"
# 5                                               None
# 6                                               None
# 7                                               None
# 8                               404 - Page Not Found
# 9                                               None
#
#                                     Meta Description
# 0                                               None
# 1  Интернет-магазин обуви и одежды в Москве. Дост...
# 2  Goede kwaliteit voor de laagst mogelijke prijs...
# 3  Masz styl z Answear.com! Odkryj modne ubrania ...
# 4  Женский журнал «ЗОЛОТОЙ» – твой верный советчи...
# 5                                               None
# 6                                               None
# 7                                               None
# 8
# 9                                               None

# %%
# ✅ Extract metadata for additional websites
df["Additional Metadata"] = df["Additional Websites"].apply(get_metadata)

# %%
df["Additional Metadata"]
# Out:
# 0      {'Meta Title': 'IÎ¤Î§ ÎÎÎÎÎ£ MONOÎ Î¡ÎÎ£Î...
# 1      {'Meta Title': None, 'Meta Description': None,...
# 2      {'Meta Title': None, 'Meta Description': None,...
# 3      {'Meta Title': None, 'Meta Description': None,...
# 4      {'Meta Title': None, 'Meta Description': None,...
#                              ...
# 485    {'Meta Title': None, 'Meta Description': None,...
# 486    {'Meta Title': None, 'Meta Description': None,...
# 487    {'Meta Title': 'HOME ZETEK', 'Meta Description...
# 488    {'Meta Title': None, 'Meta Description': None,...
# 489    {'Meta Title': None, 'Meta Description': None,...
# Name: Additional Metadata, Length: 490, dtype: object

# %%
df = df.join(pd.DataFrame(df.pop("Additional Metadata").tolist()).rename(columns={
    "Meta Title": "Additional Meta Title",
    "Meta Description": "Additional Meta Description",
    "Meta Keywords": "Additional Meta Keywords"
}))

# %%
df[["Company Name", "Website", "Meta Title", "Meta Description", "Additional Websites", "Additional Meta Title", "Additional Meta Description"]].head(10)
# Out:
#                               Company Name                     Website  \
# 0            ITX HELLAS SINGLE MEMBER S.A.                www.zara.com
# 1                                  RANDEVU          www.rendez-vous.ru
# 2                     ZEEMAN TEXTIELSUPERS              www.zeeman.com
# 3                         ANSWEAR.COM S.A.             www.answear.com
# 4                              REGENT GOLD              www.zolotoy.ru
# 5                      WOLW-POL SP. Z O.O.           www.dieselshop.pl
# 6             NILSON GROUP AB FILIAL NORGE                         NaN
# 7                               SAKURA LLC  xn--23-6kca3cvbes.xn--p1ai
# 8  LIMITED LIABILITY COMPANY HUGO BOSS RUS         www.hugoboss.com/ru
# 9                   MNG-MANGO U.K. LIMITED          www.shop.mango.com
#
#                                           Meta Title  \
# 0
# 1           Интернет-магазин обуви и одежды в Москве
# 2                 Zeeman. Zo eenvoudig kan het zijn.
# 3  Answear.com sklep internetowy z modą damską, m...
# 4                  Женский интернет-журнал "ЗОЛОТОЙ"
# 5                                               None
# 6                                               None
# 7                                               None
# 8                               404 - Page Not Found
# 9                                               None
#
#                                     Meta Description  Additional Websites  \
# 0                                               None  www.fashionwear1.gr
# 1  Интернет-магазин обуви и одежды в Москве. Дост...  www.rest-randevu.ru
# 2  Goede kwaliteit voor de laagst mogelijke prijs...                 None
# 3  Masz styl z Answear.com! Odkryj modne ubrania ...                 None
# 4  Женский журнал «ЗОЛОТОЙ» – твой верный советчи...                 None
# 5                                               None                 None
# 6                                               None                 None
# 7                                               None   ilovesakura.ru/spb
# 8                                                              www.emg.ru
# 9                                               None                 None
#
#                                Additional Meta Title  \
# 0         IÎ¤Î§ ÎÎÎÎÎ£ MONOÎ Î¡ÎÎ£Î©Î Î Î.Î.
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7  Доставка роллов, суши и пиццы в Санкт-Петербур...
# 8           Агентство маркетинговых коммуникаций EMG
# 9                                               None
#
#                          Additional Meta Description
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7  Сакура — это вкусно! Доставка суши, пиццы, кор...
# 8  EMG - креативное агентство маркетинговых комму...
# 9                                               None

# %%
df.to_csv("metadata2.csv", index=False)

# %% [markdown]
# # Translation

# %%
from deep_translator import GoogleTranslator

translator = GoogleTranslator(source="auto", target="en")

# %%
def translate_text(text):
    """Translate text to English, handling None values."""
    if pd.isna(text) or text == "None":
        return None  # Skip if no text available
    try:
        return translator.translate(text)
    except Exception as e:
        print(f"Translation error: {e}")
        return None

# %%
# ✅ Apply translation to `Meta Title` and `Meta Description`
df["Translated Meta Title"] = df["Meta Title"].apply(translate_text)
df["Translated Meta Description"] = df["Meta Description"].apply(translate_text)

# %%
df['Translated Additional Meta Title'] = df['Additional Meta Title'].apply(translate_text)
df['Translated Additional Meta Description'] = df['Additional Meta Description'].apply(translate_text)

# %%
df.to_csv("updated_metadata_with_translation.csv", index=False)

# %% [markdown]
# ## Define the Missing Cases:
# A company has no metadata available if
# - The Website column is empty or NaN.
# - The Meta Description and Additional Meta Description are both missing.

# %%
missing_info_df = df[
    (df["Website"].isna() | (df["Website"] == "")) &  # No website
    (df["Meta Description"].isna() | (df["Meta Description"] == "")) &  # No meta description
    (df["Additional Meta Description"].isna() | (df["Additional Meta Description"] == ""))  # No additional meta
]

# %%
missing_info_df
# Out:
#                                           Company Name ISO Country Code  \
# 6                         NILSON GROUP AB FILIAL NORGE               NO
# 16     ETERNA MODE GMBH ZWEIGNIEDERLASSUNG OESTERREICH               AT
# 46                              DIANITA STRUMICA DOOEL               MK
# 56                                     ZOLOTOI KVADRAT               RU
# 60   DIESEL DEUTSCHLAND GMBH ZWEIGNIEDERLASSUNG OES...               AT
# 71                          GOLD MOVING COMPANY S.R.L.               IT
# 89                             N PEAL (RETAIL) LIMITED               IE
# 90                                   DESPI ASTIGI S.L.               ES
# 111                                NIVEL PRECIOSO, LDA               PT
# 112                                          BELYETAZH               RU
# 144                                             BRENTA               RU
# 155                                                YAR               RU
# 162                       FERNER JACOBSEN AKTIESELSKAP               NO
# 175                                              ITEKS               RU
# 176                                     MARASMA S.R.L.               IT
# 177    ARGO RETAIL SOCIETA' A RESPONSABILITA' LIMITATA               IT
# 178                                       SOLUX INVEST               BE
# 186                                GROENHAUG RETAIL AS               NO
# 192                                    MAX FASHION SRL               IT
# 220                                     ONIBROX S.R.L.               IT
# 233                               ELIS GROUP IMPEX SRL               RO
# 241                                   SKOINVEST ALP AS               NO
# 246                                     BECHA - B EOOD               BG
# 254                                        GUCAMASI SA               ES
# 266              FRANCESCO ESPOSITO GIOIELLERIE S.R.L.               IT
# 269                                    EMPORIO COM SRL               RO
# 282                                      DANIEL MOSKOU               RU
# 298                               AMO DIZAJN JJ D.O.O.               HR
# 299                                  DAD & SONS S.R.L.               IT
# 304                   EUROFESHN TREJD UV IZ SKOPJE DOO               MK
# 308                                         GLN S.R.L.               IT
# 314                                             UNO-NK               ME
# 317                                         NORON EHF.               IS
# 321                     SOCIETE NANTAISE DE BIJOUTERIE               FR
# 324     ESPANSIONE SOCIETA' A RESPONSABILITA' LIMITATA               IT
# 326                                 ARIDON MOLDOVA SRL               RO
# 335                     KL MOBERG SKOTOEYFORRETNING AS               NO
# 366                                   FCR FRANCONVILLE               FR
# 367                                        OLIMPINVEST               RU
# 371                                   OESTFOLD MOTE AS               NO
# 376                                   POLARIS - S.R.L.               IT
# 379                                         SPORT CHIC               FR
# 400                                       NOSSA S.R.L.               IT
# 402                          SMART TRADING LTDOOD EOOD               BG
# 416                                     SANDVIK SKO AS               NO
# 423                             TRADIZIONE MODA S.R.L.               IT
# 426                                                DOF               RU
# 429                                   JG STORES S.R.O.               SK
# 437                                   SPY STAFF S.R.L.               IT
# 442                                              BEABA               FR
# 444                            VIOSIM IMPEX JUNIOR SRL               RO
# 452                                     IDRISI UOMO SL               ES
# 472                          INCATASCIATO GROUP S.R.L.               IT
# 485                                         ARI S.R.L.               IT
#
#                   Country                   City  \
# 6                 Norvège                   OSLO
# 16               Autriche               PARNDORF
# 46      Macédoine du Nord               STRUMICA
# 56   Fédération de Russie                 MOSCOW
# 60               Autriche                   WIEN
# 71                 Italie                   ROMA
# 89                Irlande                KILDARE
# 90                Espagne  CORNELLA DE LLOBREGAT
# 111              Portugal                 VIZELA
# 112  Fédération de Russie                   PERM
# 144  Fédération de Russie                 MOSCOW
# 155  Fédération de Russie            KRASNOYARSK
# 162               Norvège                   OSLO
# 175  Fédération de Russie            VLADIVOSTOK
# 176                Italie        NOVATE MILANESE
# 177                Italie                FIRENZE
# 178              Belgique                WAREGEM
# 186               Norvège                 BERGEN
# 192                Italie                 MILANO
# 220                Italie                   NOLA
# 233              Roumanie   BUCURESTI SECTORUL 4
# 241               Norvège              STJOERDAL
# 246              Bulgarie                  SOFIA
# 254               Espagne             PONTEVEDRA
# 266                Italie                 NAPOLI
# 269              Roumanie              CONSTANTA
# 282  Fédération de Russie                 MOSCOW
# 298               Croatie                 ZAGREB
# 299                Italie                 NAPOLI
# 304     Macédoine du Nord                 SKOPJE
# 308                Italie                TARANTO
# 314            Monténégro                 NIKSIC
# 317               Islande              REYKJAVIK
# 321                France                 NANTES
# 324                Italie                   BARI
# 326              Roumanie   BUCURESTI SECTORUL 1
# 335               Norvège                PARADIS
# 366                France           FRANCONVILLE
# 367  Fédération de Russie                  SOCHI
# 371               Norvège              TOENSBERG
# 376                Italie      PORTO SAN GIORGIO
# 379                France      NEUILLY SUR SEINE
# 400                Italie                 VARESE
# 402              Bulgarie                  SOFIA
# 416               Norvège                 GAUPNE
# 423                Italie                  PAESE
# 426  Fédération de Russie               BUINAKSK
# 429             Slovaquie       SPISSKA NOVA VES
# 437                Italie               POZZUOLI
# 442                France                  FLERS
# 444              Roumanie                   IASI
# 452               Espagne                 BILBAO
# 472                Italie           MISTERBIANCO
# 485                Italie                 VARESE
#
#                                   Address  NACE Rev. 2 Code principal  \
# 6                                     NaN                        4772
# 16                                    NaN                        4771
# 46                                    NaN                        4771
# 56                                    NaN                        4771
# 60                                    NaN                        4771
# 71                       VIA SILICELLA 47                        4777
# 89                                    NaN                        4771
# 90                                    NaN                        4777
# 111                                   NaN                        4777
# 112                                   NaN                        4771
# 144                                   NaN                        4771
# 155                                   NaN                        4771
# 162                                   NaN                        4771
# 175                                   NaN                        4771
# 176                    VIA ENRICO FERMI 7                        4771
# 177              VIA ALFONSO LAMARMORA 39                        4771
# 178                                   NaN                        2611
# 186                                   NaN                        4771
# 192               VIALE SAN GIMIGNANO 4/A                        4771
# 220         PRESSO IL CIS,ISOLA 1,TORRE 1                        4771
# 233                                   NaN                        4771
# 241                                   NaN                        4772
# 246                                   NaN                        4777
# 254                                   NaN                        4771
# 266                   PIAZZA VANVITELLI 5                        4777
# 269                                   NaN                        4771
# 282                                   NaN                        4751
# 298                                   NaN                        4771
# 299                        VIA TOLEDO 418                        4771
# 304                                   NaN                        4771
# 308                VIA PRINCIPE AMEDEO 54                        4771
# 314                                   NaN                        4772
# 317                                   NaN                        4771
# 321                               BP 1231                        4777
# 324                 VIA PASQUALE FIORE 34                        4772
# 326                                   NaN                        4771
# 335                         POSTBOKS 6083                        4772
# 366                                   NaN                        4771
# 367                                   NaN                        4771
# 371                           SJOEVEIEN 6                        4771
# 376                     VIA ENRICO MEDI 6                        4772
# 379                                   NaN                        4771
# 400                    VIALE BELFORTE 315                        4771
# 402  BUL. VITOSHA 38, MAGAZIN ROYAL HOUSE                        4777
# 416                                   NaN                        4772
# 423            VIA GIUSEPPE DI VITTORIO 2                        4771
# 426                                   NaN                        4771
# 429                                   NaN                        4772
# 437        CORSO GIUSEPPE GARIBALDI 40/44                        4771
# 442                                   NaN                        4771
# 444                                   NaN                        4771
# 452                                   NaN                        4771
# 472                                   NaN                        4771
# 485  VIA CAMILLO BENSO CONTE DI CAVOUR 39                        4771
#
#                     NACE Principal Rev. 2, description  \
# 6    Commerce de détail de chaussures et d'articles...
# 16   Commerce de détail d'habillement en magasin sp...
# 46   Commerce de détail d'habillement en magasin sp...
# 56   Commerce de détail d'habillement en magasin sp...
# 60   Commerce de détail d'habillement en magasin sp...
# 71   Commerce de détail d'articles d'horlogerie et ...
# 89   Commerce de détail d'habillement en magasin sp...
# 90   Commerce de détail d'articles d'horlogerie et ...
# 111  Commerce de détail d'articles d'horlogerie et ...
# 112  Commerce de détail d'habillement en magasin sp...
# 144  Commerce de détail d'habillement en magasin sp...
# 155  Commerce de détail d'habillement en magasin sp...
# 162  Commerce de détail d'habillement en magasin sp...
# 175  Commerce de détail d'habillement en magasin sp...
# 176  Commerce de détail d'habillement en magasin sp...
# 177  Commerce de détail d'habillement en magasin sp...
# 178            Fabrication de composants électroniques
# 186  Commerce de détail d'habillement en magasin sp...
# 192  Commerce de détail d'habillement en magasin sp...
# 220  Commerce de détail d'habillement en magasin sp...
# 233  Commerce de détail d'habillement en magasin sp...
# 241  Commerce de détail de chaussures et d'articles...
# 246  Commerce de détail d'articles d'horlogerie et ...
# 254  Commerce de détail d'habillement en magasin sp...
# 266  Commerce de détail d'articles d'horlogerie et ...
# 269  Commerce de détail d'habillement en magasin sp...
# 282  Commerce de détail de textiles en magasin spéc...
# 298  Commerce de détail d'habillement en magasin sp...
# 299  Commerce de détail d'habillement en magasin sp...
# 304  Commerce de détail d'habillement en magasin sp...
# 308  Commerce de détail d'habillement en magasin sp...
# 314  Commerce de détail de chaussures et d'articles...
# 317  Commerce de détail d'habillement en magasin sp...
# 321  Commerce de détail d'articles d'horlogerie et ...
# 324  Commerce de détail de chaussures et d'articles...
# 326  Commerce de détail d'habillement en magasin sp...
# 335  Commerce de détail de chaussures et d'articles...
# 366  Commerce de détail d'habillement en magasin sp...
# 367  Commerce de détail d'habillement en magasin sp...
# 371  Commerce de détail d'habillement en magasin sp...
# 376  Commerce de détail de chaussures et d'articles...
# 379  Commerce de détail d'habillement en magasin sp...
# 400  Commerce de détail d'habillement en magasin sp...
# 402  Commerce de détail d'articles d'horlogerie et ...
# 416  Commerce de détail de chaussures et d'articles...
# 423  Commerce de détail d'habillement en magasin sp...
# 426  Commerce de détail d'habillement en magasin sp...
# 429  Commerce de détail de chaussures et d'articles...
# 437  Commerce de détail d'habillement en magasin sp...
# 442  Commerce de détail d'habillement en magasin sp...
# 444  Commerce de détail d'habillement en magasin sp...
# 452  Commerce de détail d'habillement en magasin sp...
# 472  Commerce de détail d'habillement en magasin sp...
# 485  Commerce de détail d'habillement en magasin sp...
#
#                                                 Sector  \
# 6    Engaged in the operation of a chain of shoe st...
# 16                                                 NaN
# 46   Engaged in the operation and management of clo...
# 56   Engaged in the operation and management of clo...
# 60   Engaged in the provision of management service...
# 71    Engaged in the wholesale distribution of jewelry
# 89                                                 NaN
# 90         Engaged in the operation of a jewelry store
# 111  Engaged in the retail trade of a wide range of...
# 112                                                NaN
# 144  Engaged in the marketing and sale of furniture...
# 155  Engaged in the retail sale of clothing in spec...
# 162   Engaged in the retail trade of clothing apparels
# 175                                                NaN
# 176                                                NaN
# 177  Engaged in the operation and management of clo...
# 178  Engaged in the development, manufacture and sa...
# 186      Engaged in the retail sale of family clothing
# 192                                                NaN
# 220                                                NaN
# 233                                                NaN
# 241  Engaged in the sale of leather products in Nor...
# 246                                                NaN
# 254  Operates as a clothing store engaged in the re...
# 266                                                NaN
# 269    Engaged in the retail sale of clothing products
# 282  Engaged in the retail trade and marketing of t...
# 298                                                NaN
# 299                                                NaN
# 304                                                NaN
# 308                                                NaN
# 314  Engaged in the operation of a chain of shoe st...
# 317                                                NaN
# 321  Primarily engaged in the retail sale of jewelr...
# 324                                                NaN
# 326                                                NaN
# 335  Engaged in the operation of a chain of shoe st...
# 366                                                NaN
# 367                                                NaN
# 371           Operates as a clothing and apparel store
# 376  Engaged in the retail trade of shoes, clothes ...
# 379                                                NaN
# 400                                                NaN
# 402                                                NaN
# 416  Engaged in the management and operation of sho...
# 423  Engaged in the manufacture and distribution of...
# 426                                                NaN
# 429                                                NaN
# 437                                                NaN
# 442                                                NaN
# 444                                                NaN
# 452                                                NaN
# 472  Engaged in the operation of a chain of family ...
# 485                                                NaN
#
#                 Main activity  \
# 6                      Retail
# 16                        NaN
# 46                     Retail
# 56                     Retail
# 60                   Services
# 71                  Wholesale
# 89                        NaN
# 90                     Retail
# 111                    Retail
# 112                       NaN
# 144         Wholesale; Retail
# 155                    Retail
# 162                    Retail
# 175                       NaN
# 176                       NaN
# 177                    Retail
# 178  Manufacturing; Wholesale
# 186                    Retail
# 192                       NaN
# 220                       NaN
# 233                       NaN
# 241                 Wholesale
# 246                       NaN
# 254                    Retail
# 266                       NaN
# 269                    Retail
# 282                    Retail
# 298                       NaN
# 299                       NaN
# 304                       NaN
# 308                       NaN
# 314                    Retail
# 317                       NaN
# 321                    Retail
# 324                       NaN
# 326                       NaN
# 335                    Retail
# 366                       NaN
# 367                       NaN
# 371                    Retail
# 376                    Retail
# 379                       NaN
# 400                       NaN
# 402                       NaN
# 416                    Retail
# 423  Manufacturing; Wholesale
# 426                       NaN
# 429                       NaN
# 437                       NaN
# 442                       NaN
# 444                       NaN
# 452                       NaN
# 472                    Retail
# 485                       NaN
#
#                       Description in Original language  ...  \
# 6    SKODETALJHANDEL MED DERTIL NATURLIG HØRENDE VI...  ...
# 16                                                 NaN  ...
# 46                                                 NaN  ...
# 56                                                 NaN  ...
# 60                                                 NaN  ...
# 71   COMMERCIO ALL'INGROSSO DI OROLOGI E DI GIOIELL...  ...
# 89                                                 NaN  ...
# 90                                 Explotación joyeria  ...
# 111  Comércio a retalho de artigos de ourivesaria. ...  ...
# 112                                                NaN  ...
# 144                                                NaN  ...
# 155                                                NaN  ...
# 162  HANDEL SAMT HVA HERMED STÅR I FORBINDELSE, HER...  ...
# 175                                                NaN  ...
# 176  COMMERCIO AL DETTAGLIO DI CONFEZIONI PER BAMBI...  ...
# 177  COMMERCIO AL DETTAGLIO DI ARTICOLI DI ABBIGLIA...  ...
# 178                                                NaN  ...
# 186  HANDEL, AGENTURVIRKSOMHET OG KONSULENTVIRKSOMH...  ...
# 192    COMMERCIO AL DETTAGLIO DI CONFEZIONI PER ADULTI  ...
# 220  COMMERCIO AL DETTAGLIO DI ARTICOLI DI ABBIGLIA...  ...
# 233                                                NaN  ...
# 241                                            HANDEL.  ...
# 246                                                NaN  ...
# 254  Comercio al por menor de tejidos textiles para...  ...
# 266  COMMERCIO AL DETTAGLIO DI OROLOGI E ARTICOLI D...  ...
# 269                                                NaN  ...
# 282                                                NaN  ...
# 298                                                NaN  ...
# 299    COMMERCIO AL DETTAGLIO DI CONFEZIONI PER ADULTI  ...
# 304                                                NaN  ...
# 308  COMMERCIO AL DETTAGLIO DI ARTICOLI DI ABBIGLIA...  ...
# 314                                                NaN  ...
# 317  Tilgangur félagsins er rekstur á fataverslun á...  ...
# 321  Fabrication, vente au detail d'horlogerie, bij...  ...
# 324    COMMERCIO AL DETTAGLIO DI CALZATURE E ACCESSORI  ...
# 326                                                NaN  ...
# 335  OMSETNING AV SKOTØY OG HVA DERMED STÅR I FOR- ...  ...
# 366  Achat, vente de tout article se rapportant -di...  ...
# 367                                                NaN  ...
# 371   HANDEL, SAMT ALL ANNEN VERDISKAPENDE VIRKSOMHET.  ...
# 376    COMMERCIO AL DETTAGLIO DI CALZATURE E ACCESSORI  ...
# 379  Vente événementielle en show room. réalisation...  ...
# 400  COMMERCIO AL DETTAGLIO DI BIANCHERIA PERSONALE...  ...
# 402  ???????? ? ???????? ?????????, ??????????????,...  ...
# 416  SALG AV SKOTØY MED NATURLIG TILBEHØR, SAMT ALT...  ...
# 423  COMMERCIO AL DETTAGLIO DI ARTICOLI DI ABBIGLIA...  ...
# 426                                                NaN  ...
# 429                                                NaN  ...
# 437  COMMERCIO AL DETTAGLIO DI CONFEZIONI PER BAMBI...  ...
# 442                                                NaN  ...
# 444                                                NaN  ...
# 452  Venta al por menor de ropa, accesorios y zapat...  ...
# 472    COMMERCIO AL DETTAGLIO DI CONFEZIONI PER ADULTI  ...
# 485    COMMERCIO AL DETTAGLIO DI CONFEZIONI PER ADULTI  ...
#
#     Availability of financial data 2 years of consecutive losses  \
# 6                              YES                           YES
# 16                             YES                            NO
# 46                             YES                            NO
# 56                             YES                            NO
# 60                             YES                            NO
# 71                             YES                            NO
# 89                             YES                            NO
# 90                             YES                            NO
# 111                            YES                            NO
# 112                            YES                           YES
# 144                            YES                            NO
# 155                            YES                            NO
# 162                            YES                            NO
# 175                            YES                           YES
# 176                            YES                            NO
# 177                            YES                           YES
# 178                            YES                            NO
# 186                            YES                            NO
# 192                            YES                            NO
# 220                            YES                            NO
# 233                            YES                            NO
# 241                            YES                            NO
# 246                            YES                            NO
# 254                            YES                            NO
# 266                            YES                            NO
# 269                            YES                            NO
# 282                            YES                            NO
# 298                            YES                           YES
# 299                            YES                            NO
# 304                            YES                            NO
# 308                            YES                            NO
# 314                            YES                            NO
# 317                            YES                           YES
# 321                            YES                            NO
# 324                            YES                            NO
# 326                            YES                            NO
# 335                            YES                            NO
# 366                            YES                            NO
# 367                            YES                            NO
# 371                            YES                            NO
# 376                            YES                            NO
# 379                            YES                            NO
# 400                            YES                            NO
# 402                            YES                            NO
# 416                            YES                            NO
# 423                            YES                            NO
# 426                            YES                            NO
# 429                            YES                            NO
# 437                            YES                            NO
# 442                            YES                            NO
# 444                            YES                            NO
# 452                            YES                            NO
# 472                            YES                           YES
# 485                            YES                            NO
#
#     Average loss over 3 years Additional Websites Meta Title  \
# 6                         NaN                None       None
# 16                         NO                None       None
# 46                         NO                None       None
# 56                         NO                None       None
# 60                         NO                None       None
# 71                         NO                None       None
# 89                         NO                None       None
# 90                         NO                None       None
# 111                        NO                None       None
# 112                       NaN                None       None
# 144                        NO                None       None
# 155                        NO                None       None
# 162                        NO                None       None
# 175                       NaN                None       None
# 176                        NO                None       None
# 177                       NaN                None       None
# 178                        NO                None       None
# 186                        NO                None       None
# 192                        NO                None       None
# 220                        NO                None       None
# 233                        NO                None       None
# 241                        NO                None       None
# 246                        NO                None       None
# 254                        NO                None       None
# 266                        NO                None       None
# 269                        NO                None       None
# 282                        NO                None       None
# 298                       NaN                None       None
# 299                        NO                None       None
# 304                        NO                None       None
# 308                        NO                None       None
# 314                        NO                None       None
# 317                       NaN                None       None
# 321                        NO                None       None
# 324                        NO                None       None
# 326                        NO                None       None
# 335                        NO                None       None
# 366                        NO                None       None
# 367                        NO                None       None
# 371                        NO                None       None
# 376                       YES                None       None
# 379                        NO                None       None
# 400                        NO                None       None
# 402                        NO                None       None
# 416                        NO                None       None
# 423                        NO                None       None
# 426                        NO                None       None
# 429                       YES                None       None
# 437                        NO                None       None
# 442                        NO                None       None
# 444                        NO                None       None
# 452                        NO                None       None
# 472                       NaN                None       None
# 485                        NO                None       None
#
#      Meta Description  Meta Keywords  Additional Meta Title  \
# 6                None           None                   None
# 16               None           None                   None
# 46               None           None                   None
# 56               None           None                   None
# 60               None           None                   None
# 71               None           None                   None
# 89               None           None                   None
# 90               None           None                   None
# 111              None           None                   None
# 112              None           None                   None
# 144              None           None                   None
# 155              None           None                   None
# 162              None           None                   None
# 175              None           None                   None
# 176              None           None                   None
# 177              None           None                   None
# 178              None           None                   None
# 186              None           None                   None
# 192              None           None                   None
# 220              None           None                   None
# 233              None           None                   None
# 241              None           None                   None
# 246              None           None                   None
# 254              None           None                   None
# 266              None           None                   None
# 269              None           None                   None
# 282              None           None                   None
# 298              None           None                   None
# 299              None           None                   None
# 304              None           None                   None
# 308              None           None                   None
# 314              None           None                   None
# 317              None           None                   None
# 321              None           None                   None
# 324              None           None                   None
# 326              None           None                   None
# 335              None           None                   None
# 366              None           None                   None
# 367              None           None                   None
# 371              None           None                   None
# 376              None           None                   None
# 379              None           None                   None
# 400              None           None                   None
# 402              None           None                   None
# 416              None           None                   None
# 423              None           None                   None
# 426              None           None                   None
# 429              None           None                   None
# 437              None           None                   None
# 442              None           None                   None
# 444              None           None                   None
# 452              None           None                   None
# 472              None           None                   None
# 485              None           None                   None
#
#     Additional Meta Description Additional Meta Keywords
# 6                          None                     None
# 16                         None                     None
# 46                         None                     None
# 56                         None                     None
# 60                         None                     None
# 71                         None                     None
# 89                         None                     None
# 90                         None                     None
# 111                        None                     None
# 112                        None                     None
# 144                        None                     None
# 155                        None                     None
# 162                        None                     None
# 175                        None                     None
# 176                        None                     None
# 177                        None                     None
# 178                        None                     None
# 186                        None                     None
# 192                        None                     None
# 220                        None                     None
# 233                        None                     None
# 241                        None                     None
# 246                        None                     None
# 254                        None                     None
# 266                        None                     None
# 269                        None                     None
# 282                        None                     None
# 298                        None                     None
# 299                        None                     None
# 304                        None                     None
# 308                        None                     None
# 314                        None                     None
# 317                        None                     None
# 321                        None                     None
# 324                        None                     None
# 326                        None                     None
# 335                        None                     None
# 366                        None                     None
# 367                        None                     None
# 371                        None                     None
# 376                        None                     None
# 379                        None                     None
# 400                        None                     None
# 402                        None                     None
# 416                        None                     None
# 423                        None                     None
# 426                        None                     None
# 429                        None                     None
# 437                        None                     None
# 442                        None                     None
# 444                        None                     None
# 452                        None                     None
# 472                        None                     None
# 485                        None                     None
#
# [54 rows x 28 columns]

# %%
missing_info_df[["Company Name", "Website", "Meta Title", "Meta Description", "Additional Websites", "Additional Meta Description"]].head(20)
# Out:
#                                           Company Name Website Meta Title  \
# 6                         NILSON GROUP AB FILIAL NORGE     NaN       None
# 16     ETERNA MODE GMBH ZWEIGNIEDERLASSUNG OESTERREICH     NaN       None
# 46                              DIANITA STRUMICA DOOEL     NaN       None
# 56                                     ZOLOTOI KVADRAT     NaN       None
# 60   DIESEL DEUTSCHLAND GMBH ZWEIGNIEDERLASSUNG OES...     NaN       None
# 71                          GOLD MOVING COMPANY S.R.L.     NaN       None
# 89                             N PEAL (RETAIL) LIMITED     NaN       None
# 90                                   DESPI ASTIGI S.L.     NaN       None
# 111                                NIVEL PRECIOSO, LDA     NaN       None
# 112                                          BELYETAZH     NaN       None
# 144                                             BRENTA     NaN       None
# 155                                                YAR     NaN       None
# 162                       FERNER JACOBSEN AKTIESELSKAP     NaN       None
# 175                                              ITEKS     NaN       None
# 176                                     MARASMA S.R.L.     NaN       None
# 177    ARGO RETAIL SOCIETA' A RESPONSABILITA' LIMITATA     NaN       None
# 178                                       SOLUX INVEST     NaN       None
# 186                                GROENHAUG RETAIL AS     NaN       None
# 192                                    MAX FASHION SRL     NaN       None
# 220                                     ONIBROX S.R.L.     NaN       None
#
#     Meta Description Additional Websites Additional Meta Description
# 6               None                None                        None
# 16              None                None                        None
# 46              None                None                        None
# 56              None                None                        None
# 60              None                None                        None
# 71              None                None                        None
# 89              None                None                        None
# 90              None                None                        None
# 111             None                None                        None
# 112             None                None                        None
# 144             None                None                        None
# 155             None                None                        None
# 162             None                None                        None
# 175             None                None                        None
# 176             None                None                        None
# 177             None                None                        None
# 178             None                None                        None
# 186             None                None                        None
# 192             None                None                        None
# 220             None                None                        None

# %%
# Tran
